# %% [markdown]
# <a href="https://colab.research.google.com/github/laugustovieira/BootCamp-Data-Science/blob/main/Desafios_Modulo1_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importar Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# #Carga de Dados

# %%
dados = pd.read_csv("/content/drive/MyDrive/Dados_BootCamp/A004854189_28_143_208_2021_PROCESSAMENTO.csv", encoding="ISO-8859-1", skiprows=3,
                  skipfooter = 12, sep=";", thousands = '.', decimal = ',', engine = "python")

# %% [markdown]
# #Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
eixo_x = "Unidade da Federação"
eixo_y = "2008/Ago"
dados = dados.sort_values(by=eixo_y, ascending=False)
ax = dados.plot(x = eixo_x, y = eixo_y, kind= "bar", figsize = [10,7])
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
titulo = "SUS: Gastos com procedimentos hospitalares por Unidade da Federação em {}".format(eixo_y)
plt.title(titulo)
# Out:
# Text(0.5, 1.0, 'SUS: Gastos com procedimentos hospitalares por Unidade da Federação em 2008/Ago')

# %% [markdown]
# #Desafio 02: Fazer a mesma análise para o mês mais recente

# %%
eixo_x = "Unidade da Federação"
eixo_y = dados.columns[-2]
dados = dados.replace("-",0)
dados[eixo_y] = dados[eixo_y].astype("float64")
dados = dados.sort_values(by=eixo_y, ascending=False)
ax = dados.plot(x = eixo_x, y = eixo_y, kind= "bar", figsize = [10,6])
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
titulo = "SUS: Gastos com procedimentos hospitalares por Unidade da Federação em {}".format(eixo_y)
plt.title(titulo)
plt.show()
