# %% [markdown]
# <a href="https://colab.research.google.com/github/laugustovieira/BootCamp-Data-Science/blob/main/BootCampDataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Realizando a leitura do arquivo, colocando no formato brasil pois está em utf-8, pulando as 3 primeiras linhas, utilizando o separador ";"

# %%
dados = pd.read_csv("/content/drive/MyDrive/Dados_BootCamp/A005117189_28_143_208_2021_ATENDIMENTO.csv", encoding = "ISO-8859-1", skiprows= 3, sep= ";",skipfooter=12,
                    engine = 'python', thousands= ".", decimal=",")
dados.head() #verificar o inicio da tabela
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
dados.tail() #verificar o final da tabela
# Out:
#      Unidade da Federação 1992/Mar  ...    2021/Mar          Total
# 22   43 Rio Grande do Sul        -  ... 37798832.80 12764391179.92
# 23  50 Mato Grosso do Sul        -  ...  4035989.77  2324525096.33
# 24         51 Mato Grosso        -  ...  8835890.09  2180119781.15
# 25               52 Goiás        -  ... 24867001.02  4973572261.43
# 26    53 Distrito Federal        -  ... 14731938.43  2592422853.56
#
# [5 rows x 287 columns]

# %%
dados.mean() #leitura da media, porém com valores elevados a 7
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format # formatando em duas casas decimais

# %%
dados.mean() # dados já formatados
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados["2008/Ago"].mean() #media da coluna de agosta
# Out:
# 26641365.101481482

# %%
dados.plot(x = "Unidade da Federação", y="2008/Ago", kind = "bar", figsize=(10,7))
#plotando um gráfico das unidades da federação dos gastos do mês de agosto em barra com um tamanho 10,7

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x = "Unidade da Federação", y="2008/Ago", kind = "bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #formatar o eixo y
plt.title(" VAlor por Unidade da Federação")
# Out:
# Text(0.5, 1.0, ' VAlor por Unidade da Federação')

# %% [markdown]
# #Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
ax = dados.plot(x = "Unidade da Federação", y="2008/Ago", kind = "bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #formatar o eixo y
plt.title(" Gastos do SUS por Unidade da Federação")
# Out:
# Text(0.5, 1.0, ' Gastos do SUS por Unidade da Federação')

# %% [markdown]
# #Desafio 02: Fazer a mesma análise para o mês mais recente

# %%
dados = dados.replace("-",0)
mes_mais_recente = dados.columns[-2] # pegar a ultima coluna
mes_mais_recente

dados["2020/Ago"] = dados["2020/Ago"].astype("float64") #converte coluna para float
dados = dados.sort_values(by=mes_mais_recente, ascending= False) # ordenação da informação

ax = dados.plot(x = "Unidade da Federação", y=mes_mais_recente, kind = "bar", figsize=(10,4))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gasto do SUS por Unidade da Federação")
# Out:
# Text(0.5, 1.0, 'Gasto do SUS por Unidade da Federação')

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#        2008/Ago     2008/Set
# 19 180005050.15 180151656.17
# 16  80374117.08  82409129.30
# 18  42500830.29  43066461.47
# 20  56699001.13  58091985.79
# 12  31705296.79  30703879.20

# %% [markdown]
# #Aula 2

# %%
colunas_usaveis = dados.mean().index.tolist() # importante usar o tolist para transformar 
                                              # em uma lista de python que é mutável. O index não é
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis
# Out:
#       Unidade da Federação   2007/Ago  ...     2021/Mar          Total
# 19            35 São Paulo 1665349.90  ... 177408317.71 41396408548.81
# 16         31 Minas Gerais  971394.37  ...  79780838.00 20418737536.66
# 18       33 Rio de Janeiro  469469.34  ...  49149884.48 10337389922.09
# 20               41 Paraná  554800.22  ...  43480729.07 14681514706.67
# 12           26 Pernambuco  400640.85  ...  39472738.81  8581189975.91
# 22    43 Rio Grande do Sul 1049252.33  ...  37798832.80 12764391179.92
# 15                29 Bahia  135146.36  ...  31314602.44  9791541570.52
# 25                52 Goiás  179395.82  ...  24867001.02  4973572261.43
# 21       42 Santa Catarina  693955.05  ...  19375822.56  7835011163.40
# 7              21 Maranhão  385330.18  ...  17294509.11  3871069498.04
# 9                 23 Ceará  357904.65  ...  17173151.55  6591836650.18
# 17       32 Espírito Santo   57408.11  ...  15606368.11  3405850698.58
# ...

# %%
#criando um indice
usaveis = usaveis.set_index("Unidade da Federação")

# %%
#buscar a linha deste indice
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
#virou a tabela (Linas passa a ser colunas e colunas passam a ser linhas) e plota o gráfico
#ficou distorcido por causa que o total está sendo considerado
usaveis.T.plot(figsize=(12,6))

# %%
#Retirar o total
usaveis = usaveis.drop("Total", axis=1) # 0coluna 1 linha

# %%
usaveis.T.plot(figsize= (12,6))

# %% [markdown]
# #Desafio 01 : Colocar a legenda separada

# %%
ax = usaveis.T.plot(figsize= (12,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1,1.1)) 
plt.title("Custo Total do Atendimento por Unidade da Federação")
# Out:
# Text(0.5, 1.0, 'Custo Total do Atendimento por Unidade da Federação')

# %% [markdown]
# #Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferencia

# %%
estados_selecionados = ["35 São Paulo","31 Minas Gerais", "33 Rio de Janeiro", 
                        "32 Espírito Santo", "41 Paraná"]
ax = usaveis.T[estados_selecionados].plot(figsize= (12,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.2,0.7)) 
plt.title("Custo Total do Atendimento por Unidade da Federação")
# Out:
# Text(0.5, 1.0, 'Custo Total do Atendimento por Unidade da Federação')

# %% [markdown]
# # Aula 03

# %% [markdown]
# #Desafio 01 : Mudar a Palete de cores com o matplotlib
#
# #Desafio 02 : Adicionar uma coluna mostrando a região de cada estado
#
# #Desafio 03: Grafico mais bonito (Titulo, legenda e escala)
#
# #Desafio 04: Adicione seu estado aos 5 estados existentes e plote
#
# #Desafio 05: plotar o gráfico da região sudeste e verificar se afetou o pico 2012/2013
#
# #Desafio 06: Adicionar o seu estado e deixe o gráfico com as informações claras

# %%
usaveis.T.columns[0:5] #cinco primiros da tabela transposta. Pega pelas colunas
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '41 Paraná',
#        '26 Pernambuco'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.index[0:5] #cinco primeiro usando index. Neste caso pega pelas linhas
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '41 Paraná',
#        '26 Pernambuco'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis[0:5].T.plot(figsize=(10,6))

# %%
usaveis.head(20)
# Out:
#                          2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                          ...
# 35 São Paulo           1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais         971394.37 2861781.50  ... 119877417.15  79780838.00
# 33 Rio de Janeiro       469469.34  921646.57  ...  60873103.08  49149884.48
# 41 Paraná               554800.22 1431708.01  ...  83130175.37  43480729.07
# 26 Pernambuco           400640.85 1088340.42  ...  62259409.32  39472738.81
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  84404640.00  37798832.80
# 29 Bahia                135146.36  448349.75  ...  55544579.04  31314602.44
# 52 Goiás                179395.82  418053.58  ...  32253788.65  24867001.02
# 42 Santa Catarina       693955.05 1092964.12  ...  47429335.91  19375822.56
# 21 Maranhão             385330.18 1018352.93  ...  23260245.95  17294509.11
# 23 Ceará                357904.65  572356.18  ...  30186951.00  17173151.55
# ...

# %%
import numpy as np

np.random.seed(687942) #setando a semente para sempre gerar o mesmo resultado
usaveis.sample(n=7)
# Out:
#                          2007/Ago   2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                          ...
# 24 Rio Grande do Norte  134605.36  272088.08  ... 18186942.80  8733455.36
# 51 Mato Grosso           63562.50  232444.62  ... 13207979.82  8835890.09
# 23 Ceará                357904.65  572356.18  ... 30186951.00 17173151.55
# 29 Bahia                135146.36  448349.75  ... 55544579.04 31314602.44
# 17 Tocantins              4113.76   76633.06  ...   416534.32   928756.84
# 14 Roraima                4785.91   11858.63  ...  3044798.77  2381844.31
# 43 Rio Grande do Sul   1049252.33 3182913.14  ... 84404640.00 37798832.80
#
# [7 rows x 164 columns]

# %%
usaveis.sample(n=7) #sem o uso da semente aparecem resultados diferentes
# Out:
#                         2007/Ago  2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                        ...
# 50 Mato Grosso do Sul  199556.12 573675.41  ... 11428462.42  4035989.77
# 27 Alagoas             104243.75 174024.90  ... 12792571.64  8180887.21
# 51 Mato Grosso          63562.50 232444.62  ... 13207979.82  8835890.09
# 13 Amazonas             35752.72  45570.64  ... 13679358.06  6799060.80
# 52 Goiás               179395.82 418053.58  ... 32253788.65 24867001.02
# 16 Amapá                33672.74 104822.98  ...  1534733.18   989155.40
# 24 Rio Grande do Norte 134605.36 272088.08  ... 18186942.80  8733455.36
#
# [7 rows x 164 columns]

# %%
#Adicionando uma coluna de total

usaveis.sum(axis=1)
usaveis["Total"] = usaveis.sum(axis=1)
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41386533231.31
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418205467.78
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337229379.18
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681341476.16
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8580915668.43
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764274442.95
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791496136.10
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973505000.10
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7834872054.38
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871010362.58
# ...

# %%
ordenado_por_total = usaveis.sort_values(by="Total", ascending=False)
ordenado_por_total = ordenado_por_total.drop("Total",axis= 1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 41 Paraná             554800.22 1431708.01  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
#
# [5 rows x 164 columns]

# %%
ordenado_por_total_todos = ordenado_por_total
ordenado_por_total_todos = ordenado_por_total_todos[ordenado_por_total_todos.columns[6:]]
ordenado_por_total_todos = ordenado_por_total_todos/1000000

# %%
ordenado_por_total.head().T.plot(figsize=(10,6))

# %%
ordenado_por_total = usaveis.nlargest(5,"Total") #buscar os cinco com maior gasto
ordenado_por_total = ordenado_por_total.drop("Total",axis=1)
ordenado_por_total.T.plot(figsize=(10,6))

# %%
ordenado_por_total = usaveis.nsmallest(5,"Total") #buscar os cinco com menor gasto
ordenado_por_total = ordenado_por_total.drop("Total",axis=1)
ordenado_por_total = ordenado_por_total/1000000
ordenado_por_total.T.plot(figsize=(10,6))

# %%
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 177408317.71 41386533231.31
# 31 Minas Gerais       971394.37 2861781.50  ...  79780838.00 20418205467.78
# 33 Rio de Janeiro     469469.34  921646.57  ...  49149884.48 10337229379.18
# 41 Paraná             554800.22 1431708.01  ...  43480729.07 14681341476.16
# 26 Pernambuco         400640.85 1088340.42  ...  39472738.81  8580915668.43
#
# [5 rows x 165 columns]

# %%
# buscando as colunas interessadas. Desconsiderando os picos 
ordenado_por_total = usaveis.nlargest(5,"Total") #buscar os cinco com maior gasto
ordenado_por_total = ordenado_por_total.drop("Total",axis=1)
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]
ordenado_por_total = ordenado_por_total/1000000
ordenado_por_total.T.plot(figsize=(12,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0,350) #importante para manter a mesma escala para a análise. Sem esta linha pode deturpar a informação
# Out:
# (0.0, 350.0)

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100,350)
# Out:
# (100.0, 350.0)

# %% [markdown]
# Deve-se tomar cuidado com maneira de plotar o gráfico, pois dependendo da largura definida, do corte que se fizer no gráfico, pode se dar uma má impressão da inforamção

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %% [markdown]
# Parce que os custos estão subindo mais rápido

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(6,6))

# %% [markdown]
# Parece que o gráfico está constante

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(20,6))

# %% [markdown]
# #Aula 05

# %%
mes_mais_recente = usaveis.columns[-2]
mes_mais_recente
# Out:
# '2021/Mar'

# %%
gastos_do_mais_recente = usaveis[mes_mais_recente]
gastos_do_mais_recente = gastos_do_mais_recente/1000000
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo        177.41
# 31 Minas Gerais      79.78
# 33 Rio de Janeiro    49.15
# 41 Paraná            43.48
# 26 Pernambuco        39.47
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot()

# %%
gastos_do_mais_recente.plot(kind="pie")

# %% [markdown]
# Horrores das pizza:
# - legenda horrivel
# - número de fatias inacreditável
#
# já estamos com vantagem
#
#  - Gráfico veio ordenado

# %%
gastos_do_mais_recente.sample(frac=1).plot(kind="pie")

# %% [markdown]
# Horrores das pizza atual:
# - legenda horrivel
# - número de fatias inacreditável
# - não dá para saber a ordem
# - cores repetidas
# - ruim para definir ordem
# - péssimo para COMPARAR

# %%
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             177.41
# 31 Minas Gerais           79.78
# 33 Rio de Janeiro         49.15
# 41 Paraná                 43.48
# 26 Pernambuco             39.47
# 43 Rio Grande do Sul      37.80
# 29 Bahia                  31.31
# 52 Goiás                  24.87
# 42 Santa Catarina         19.38
# 21 Maranhão               17.29
# 23 Ceará                  17.17
# 32 Espírito Santo         15.61
# 53 Distrito Federal       14.73
# 15 Pará                   13.07
# 25 Paraíba                12.52
# 22 Piauí                   9.54
# 51 Mato Grosso             8.84
# 24 Rio Grande do Norte     8.73
# 27 Alagoas                 8.18
# 13 Amazonas                6.80
# 11 Rondônia                4.73
# 50 Mato Grosso do Sul      4.04
# 28 Sergipe                 3.08
# 14 Roraima                 2.38
# 12 Acre                    1.14
# 16 Amapá                   0.99
# 17 Tocantins               0.93
# Name: 2021/Mar, dtype: float64

# %% [markdown]
# Para saber o quanto os estados gastaram mais que o Rio de Janeiro

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.61
# 31 Minas Gerais          1.62
# 33 Rio de Janeiro        1.00
# 41 Paraná                0.88
# 26 Pernambuco            0.80
# 43 Rio Grande do Sul     0.77
# 29 Bahia                 0.64
# 52 Goiás                 0.51
# 42 Santa Catarina        0.39
# 21 Maranhão              0.35
# 23 Ceará                 0.35
# 32 Espírito Santo        0.32
# 53 Distrito Federal      0.30
# 15 Pará                  0.27
# 25 Paraíba               0.25
# 22 Piauí                 0.19
# 51 Mato Grosso           0.18
# 24 Rio Grande do Norte   0.18
# 27 Alagoas               0.17
# 13 Amazonas              0.14
# 11 Rondônia              0.10
# 50 Mato Grosso do Sul    0.08
# 28 Sergipe               0.06
# 14 Roraima               0.05
# 12 Acre                  0.02
# 16 Amapá                 0.02
# 17 Tocantins             0.02
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["31 Minas Gerais"]
# Out:
# Unidade da Federação
# 35 São Paulo             2.22
# 31 Minas Gerais          1.00
# 33 Rio de Janeiro        0.62
# 41 Paraná                0.55
# 26 Pernambuco            0.49
# 43 Rio Grande do Sul     0.47
# 29 Bahia                 0.39
# 52 Goiás                 0.31
# 42 Santa Catarina        0.24
# 21 Maranhão              0.22
# 23 Ceará                 0.22
# 32 Espírito Santo        0.20
# 53 Distrito Federal      0.18
# 15 Pará                  0.16
# 25 Paraíba               0.16
# 22 Piauí                 0.12
# 51 Mato Grosso           0.11
# 24 Rio Grande do Norte   0.11
# 27 Alagoas               0.10
# 13 Amazonas              0.09
# 11 Rondônia              0.06
# 50 Mato Grosso do Sul    0.05
# 28 Sergipe               0.04
# 14 Roraima               0.03
# 12 Acre                  0.01
# 16 Amapá                 0.01
# 17 Tocantins             0.01
# Name: 2021/Mar, dtype: float64

# %% [markdown]
# Perceba que São Paulo tem um gasto de 223% em relação a minas gerais
# Rio de Janeiro tem um gasto de 62% em relação a Minas Gerais

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["31 Minas Gerais"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo        2.22
# 31 Minas Gerais     1.00
# 33 Rio de Janeiro   0.62
# 41 Paraná           0.55
# 26 Pernambuco       0.49
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot(kind="bar")

# %% [markdown]
# Acima está apresentando por uma ordem pelo total.
# Vamos apresentar pela ordem do mÊs

# %%
#não precisa a coluna pois já está selecionada apenas uma coluna
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind="bar")

# %% [markdown]
# Aqui consegue-se visualizar a ordem, é possível comparar, ou seja, tudo que o gráfico de pizza não permite aqui é possível

# %% [markdown]
# #Módulo 02
# ##Aula 01

# %%
#não precisa a coluna pois já está selecionada apenas uma coluna
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind="bar")

# %%
gastos_porporcionais = gastos_do_mais_recente/gastos_do_mais_recente.sum()
gastos_porporcionais.plot(kind="bar")

# %%
ibge_estimativa = pd.read_excel("https://github.com/laugustovieira/BootCamp-Data-Science/raw/main/dados/POP2020_20210331.xls")
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  ...          Unnamed: 2
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO                                                                  ...  POPULAÇÃO ESTIMADA
# 1                                             Brasil                                                                  ...           211755692
# 2                                       Região Norte                                                                  ...            18672591
# 3                                           Rondônia                                                                  ...             1796460
# 4                                               Acre                                                                  ...              894470
#
# [5 rows x 3 columns]

# %%
# tabela extraida do wikipdia no seguinte endereço  - https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o
# transformar esta tabela em um data frame
dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 292 666	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 252 502	3,4%	 Sérvia (7 114 393)
11	 Maranhão	7 114 598	3,4%	 Paraguai (7 003 406)
12	 Goiás	7 113 540	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 207 714	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

# %%
#resultado
from io import StringIO
dados_da_populacao_io = StringIO(dados_da_populacao)
populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
#eliminando as linhas vazias
populacao = populacao.dropna()
#tem que usar o str para pegar a string do campo.
#eliminando os espaços vazios
#converendo a coluna para inteiro
populacao["populacao"] = populacao["População"].str.replace(" ", "").astype(int)
populacao["uf"] = populacao["Unidade federativa"]
populacao = populacao[["uf", "populacao"]]
populacao = populacao.set_index("uf")
display(populacao.head())
display(populacao.info())
# Out:
#                  populacao
# uf
#  São Paulo        46289333
#  Minas Gerais     21292666
#  Rio de Janeiro   17366189
# Bahia Bahia       14930634
#  Paraná           11516840
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries,  São Paulo to  Roraima
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   populacao  27 non-null     int64
# dtypes: int64(1)
# memory usage: 432.0+ bytes
# None

# %%
#mostrando os 3 primeiros da lista
populacao.index[:3]
# Out:
# Index([' São Paulo', ' Minas Gerais', ' Rio de Janeiro'], dtype='object', name='uf')

# %%
#mostrando os 3 primeiros caracteres
populacao.index.str[:3]
# Out:
# Index([' Sã', ' Mi', ' Ri', 'Bah', ' Pa', ' Ri', ' Pe', ' Ce', 'Par', ' Sa',
#        ' Ma', ' Go', ' Am', ' Es', ' Pa', ' Ri', ' Ma', ' Al', ' Pi', ' Di',
#        ' Ma', ' Se', ' Ro', ' To', ' Ac', ' Am', ' Ro'],
#       dtype='object', name='uf')

# %%
gastos_do_mais_recente.index = gastos_do_mais_recente.index.str[3:]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo        177.41
# Minas Gerais      79.78
# Rio de Janeiro    49.15
# Paraná            43.48
# Pernambuco        39.47
# Name: 2021/Mar, dtype: float64

# %%
populacao
# Out:
#                       populacao
# uf
#  São Paulo             46289333
#  Minas Gerais          21292666
#  Rio de Janeiro        17366189
# Bahia Bahia            14930634
#  Paraná                11516840
#  Rio Grande do Sul     11422973
#  Pernambuco             9616621
#  Ceará                  9187103
# Pará Pará               8690745
#  Santa Catarina         7252502
#  Maranhão               7114598
#  Goiás                  7113540
#  Amazonas               4207714
#  Espírito Santo         4064052
#  Paraíba                4039277
#  Rio Grande do Norte    3534165
#  Mato Grosso            3526220
#  Alagoas                3351543
#  Piauí                  3281480
#  Distrito Federal       3055149
#  Mato Grosso do Sul     2809394
#  Sergipe                2318822
#  Rondônia               1796460
#  Tocantins              1590248
#  Acre                    894470
#  Amapá                   861773
#  Roraima                 631181

# %%
# realizar o join entre os 2 dataframes

populacao.join(gastos_do_mais_recente)
# Out:
#                       populacao  2021/Mar
# uf
#  São Paulo             46289333       nan
#  Minas Gerais          21292666       nan
#  Rio de Janeiro        17366189       nan
# Bahia Bahia            14930634       nan
#  Paraná                11516840       nan
#  Rio Grande do Sul     11422973       nan
#  Pernambuco             9616621       nan
#  Ceará                  9187103       nan
# Pará Pará               8690745       nan
#  Santa Catarina         7252502       nan
#  Maranhão               7114598       nan
#  Goiás                  7113540       nan
#  Amazonas               4207714       nan
#  Espírito Santo         4064052       nan
#  Paraíba                4039277       nan
#  Rio Grande do Norte    3534165       nan
#  Mato Grosso            3526220       nan
#  Alagoas                3351543       nan
#  Piauí                  3281480       nan
#  Distrito Federal       3055149       nan
#  Mato Grosso do Sul     2809394       nan
# ...

# %%
#não faz o join porque existe espaço no indice
populacao.index[0]
# Out:
# ' São Paulo'

# %%
#retirar os espacos
populacao.index[0].strip()
# Out:
# 'São Paulo'

# %%
#retirando o espaco dos indices
populacao.index = populacao.index.str.strip()
populacao.head()
# Out:
#                 populacao
# uf
# São Paulo        46289333
# Minas Gerais     21292666
# Rio de Janeiro   17366189
# Bahia Bahia      14930634
# Paraná           11516840

# %%
#refazendo o join
populacao.join(gastos_do_mais_recente)
# Out:
#                      populacao  2021/Mar
# uf
# São Paulo             46289333    177.41
# Minas Gerais          21292666     79.78
# Rio de Janeiro        17366189     49.15
# Bahia Bahia           14930634       nan
# Paraná                11516840     43.48
# Rio Grande do Sul     11422973     37.80
# Pernambuco             9616621     39.47
# Ceará                  9187103     17.17
# Pará Pará              8690745       nan
# Santa Catarina         7252502     19.38
# Maranhão               7114598     17.29
# Goiás                  7113540     24.87
# Amazonas               4207714      6.80
# Espírito Santo         4064052     15.61
# Paraíba                4039277     12.52
# Rio Grande do Norte    3534165      8.73
# Mato Grosso            3526220      8.84
# Alagoas                3351543      8.18
# Piauí                  3281480      9.54
# Distrito Federal       3055149     14.73
# Mato Grosso do Sul     2809394      4.04
# Sergipe                2318822      3.08
# ...

# %%
#como Bahia e Para não fez o Join por estar bahia bahia e Pará Pará 
#é necessário fazer um string replace
for estado in gastos_do_mais_recente.index:
  populacao.index = populacao.index.str.replace(f"{estado} {estado}",estado)
populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Maranhão', 'Goiás', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
#refazendo o join
gastos_e_populacao_recente = populacao.join(gastos_do_mais_recente)
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2021/Mar
# uf
# São Paulo        46289333    177.41
# Minas Gerais     21292666     79.78
# Rio de Janeiro   17366189     49.15
# Bahia            14930634     31.31
# Paraná           11516840     43.48

# %% [markdown]
# #Módulo 02 Aula 02

# %%
# horripilante (misturando informações de população e dinheiro no mesmo eixo)
gastos_e_populacao_recente["gastos"] = gastos_e_populacao_recente["2021/Mar"] * 1000000
gastos_e_populacao_recente[["gastos", "populacao"]].plot()

# %%
gastos_e_populacao_recente.loc[["Rio Grande do Sul","São Paulo"]]
# Out:
#                    populacao  2021/Mar       gastos
# uf
# Rio Grande do Sul   11422973     37.80  37798832.80
# São Paulo           46289333    177.41 177408317.71

# %% [markdown]
# perceba que os gastos por habitante é praticamente o mesmo, mas o gráfico acima deu uma sensação que era muito maior, devido as escalas e uso de duas informaçãoes totalmente diferentes dentro o mesmo eixo

# %%
gastos_e_populacao_recente["gastos"].loc[["Rio Grande do Sul","São Paulo"]]/ gastos_e_populacao_recente["populacao"].loc[["Rio Grande do Sul","São Paulo"]]
# Out:
# uf
# Rio Grande do Sul   3.31
# São Paulo           3.83
# dtype: float64

# %%
# criar uma tabela com os gastos por habitante

gastos_e_populacao_recente["gasto_por_habitante"] = gastos_e_populacao_recente["gastos"]/ gastos_e_populacao_recente["populacao"]
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2021/Mar       gastos  gasto_por_habitante
# uf
# São Paulo        46289333    177.41 177408317.71                 3.83
# Minas Gerais     21292666     79.78  79780838.00                 3.75
# Rio de Janeiro   17366189     49.15  49149884.48                 2.83
# Bahia            14930634     31.31  31314602.44                 2.10
# Paraná           11516840     43.48  43480729.07                 3.78

# %% [markdown]
# o gráfico está ordenado por aqueles que gastam mais. Isto nos mostra que o estado que gasta mais ainda assim está abaixo em gastos/habitante do que outros estados como distrito federal por exemplo

# %%
gastos_e_populacao_recente["gasto_por_habitante"].plot(kind="bar", figsize=(12,6))

# %%
  import seaborn as sns
  sns.scatterplot(data=gastos_e_populacao_recente/1000000, x="populacao",y="gastos" )

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=gastos_e_populacao_recente/1000000, x="populacao",y="gastos" )

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao",y="gasto_por_habitante" )

# %%
ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  ...  2021/Fev  2021/Mar
# Unidade da Federação                      ...
# 35 São Paulo            172.96    170.56  ...    268.19    177.41
# 31 Minas Gerais          70.30     79.12  ...    119.88     79.78
# 41 Paraná                48.86     55.61  ...     83.13     43.48
# 43 Rio Grande do Sul     45.90     52.93  ...     84.40     37.80
# 33 Rio de Janeiro        44.13     42.90  ...     60.87     49.15
#
# [5 rows x 158 columns]

# %%
#apresentar todoas as colunas do mÊs do estado de são paulo. Não bom fazer assim.
sns.scatterplot(x=ordenado_por_total.columns, y=ordenado_por_total.loc["35 São Paulo"])

# %%
#Este seria mais ideal, pois "São Paulo" vira uma coluna e pode-se apresentar os meses e passando o dataFrame no método
sns.scatterplot(data = ordenado_por_total.T, x=ordenado_por_total.T.index, y="35 São Paulo")

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = ordenado_por_total.T, x=ordenado_por_total.T.index, y="35 São Paulo")
plt.xticks(rotation=30)
# define o eixo x de 12 em 12 meses com inicio em janeiro
ax.xaxis.set_major_locator(ticker.IndexLocator(base=12,offset=11))
plt.grid(True, linestyle='--')
plt.ylim(0,400)
# colocar como o método achar melhor a representação do eixo x
#ax.xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
from datetime import datetime

mensal = ordenado_por_total_todos.T

mensal.index
# Out:
# Index(['2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai', '2008/Jun', '2008/Jul',
#        '2008/Ago', '2008/Set', '2008/Out', '2008/Nov',
#        ...
#        '2020/Jun', '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov',
#        '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar'],
#       dtype='object', length=158)

# %%
#usando um dicionário
meses = {"Jan": 1,
         "Fev": 2,
         "Mar": 3,
         "Abr": 4,
         "Mai": 5,
         "Jun": 6,
         "Jul": 7,
         "Ago": 8,
         "Set": 9,
         "Out": 10,
         "Nov": 11,
         "Dez": 12
         }
#definindo um método para ajustar as datas
def para_data(mes_ano):
  ano = int(mes_ano[0:4])
  mes = meses[mes_ano[5:8]]
  return date(ano, mes, 1)

#realizar o map para ajustar todas as datas do indice
mensal.index = mensal.index.map(para_data)

# %%
mensal.index
# Out:
# Index([2008-02-01, 2008-03-01, 2008-04-01, 2008-05-01, 2008-06-01, 2008-07-01,
#        2008-08-01, 2008-09-01, 2008-10-01, 2008-11-01,
#        ...
#        2020-06-01, 2020-07-01, 2020-08-01, 2020-09-01, 2020-10-01, 2020-11-01,
#        2020-12-01, 2021-01-01, 2021-02-01, 2021-03-01],
#       dtype='object', length=158)

# %%
mensal.head()
# Out:
# Unidade da Federação  35 São Paulo  31 Minas Gerais  ...  14 Roraima  16 Amapá
# 2008-02-01                  172.96            70.30  ...        0.77      1.28
# 2008-03-01                  170.56            79.12  ...        0.88      1.18
# 2008-04-01                  170.34            79.05  ...        0.90      1.40
# 2008-05-01                  172.46            79.27  ...        1.03      1.41
# 2008-06-01                  175.49            79.62  ...        0.94      1.42
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal, x=mensal.index, y="35 São Paulo")
plt.xticks(rotation=30)
#comentando a linha abaixo percebe que o plota o gráfico por ano
#ax.xaxis.set_major_locator(ticker.IndexLocator(base=12,offset=11))
plt.grid(True, linestyle='--')
plt.ylim(0,400)
# colocar como o método achar melhor a representação do eixo x
#ax.xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal, x=mensal.index, y="35 São Paulo")
ax = sns.lineplot(data = mensal, x=mensal.index, y="31 Minas Gerais")
plt.xticks(rotation=30)
#comentando a linha abaixo percebe que o plota o gráfico por ano
#ax.xaxis.set_major_locator(ticker.IndexLocator(base=12,offset=11))
plt.grid(True, linestyle='--')
plt.ylim(0,400)
# colocar como o método achar melhor a representação do eixo x
#ax.xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %% [markdown]
# Não utilizar copia do plot para imprimir dois estados.

# %%
mensal_aberto = mensal.reset_index().melt(id_vars=["index"], value_vars = mensal.columns)
mensal_aberto.columns = ["dia_mes_ano", "uf","gasto"]
mensal_aberto["dia_mes_ano"] = mensal_aberto["dia_mes_ano"].astype("datetime64")

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto, x="dia_mes_ano", y="gasto", hue="uf")
plt.xticks(rotation=30)
#comentando a linha abaixo percebe que o plota o gráfico por ano
#ax.xaxis.set_major_locator(ticker.IndexLocator(base=12,offset=11))
plt.grid(True, linestyle='--')
plt.ylim(0,400)
# colocar como o método achar melhor a representação do eixo x
#ax.xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %% [markdown]
# ##Módulo 02 Aula 05

# %%
mensal_aberto.head()
# Out:
#           mes            uf  gasto
# 0  2008-02-01  35 São Paulo 172.96
# 1  2008-03-01  35 São Paulo 170.56
# 2  2008-04-01  35 São Paulo 170.34
# 3  2008-05-01  35 São Paulo 172.46
# 4  2008-06-01  35 São Paulo 175.49

# %%
mensal_aberto["mes"] = mensal_aberto["dia_mes_ano"].dt.month
mensal_aberto["ano"] = mensal_aberto["dia_mes_ano"].dt.year
mensal_aberto.head()
# Out:
#   dia_mes_ano            uf  gasto  mes   ano
# 0  2008-02-01  35 São Paulo 172.96    2  2008
# 1  2008-03-01  35 São Paulo 170.56    3  2008
# 2  2008-04-01  35 São Paulo 170.34    4  2008
# 3  2008-05-01  35 São Paulo 172.46    5  2008
# 4  2008-06-01  35 São Paulo 175.49    6  2008

# %%
mensal_aberto.query("uf=='35 São Paulo'")
# Out:
#     dia_mes_ano            uf  gasto  mes   ano
# 0    2008-02-01  35 São Paulo 172.96    2  2008
# 1    2008-03-01  35 São Paulo 170.56    3  2008
# 2    2008-04-01  35 São Paulo 170.34    4  2008
# 3    2008-05-01  35 São Paulo 172.46    5  2008
# 4    2008-06-01  35 São Paulo 175.49    6  2008
# ..          ...           ...    ...  ...   ...
# 153  2020-11-01  35 São Paulo 324.60   11  2020
# 154  2020-12-01  35 São Paulo 326.85   12  2020
# 155  2021-01-01  35 São Paulo 324.12    1  2021
# 156  2021-02-01  35 São Paulo 268.19    2  2021
# 157  2021-03-01  35 São Paulo 177.41    3  2021
#
# [158 rows x 5 columns]

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf=='35 São Paulo'"), x="mes", y="gasto", hue="ano", palette="inferno")
plt.xticks(rotation=30)
#comentando a linha abaixo percebe que o plota o gráfico por ano
#ax.xaxis.set_major_locator(ticker.IndexLocator(base=12,offset=11))
plt.grid(True, linestyle='--')
plt.ylim(0,400)
# colocar como o método achar melhor a representação do eixo x
#ax.xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
dias_mes = {1:31,
            2:28,
            3:31,
            4:30,
            5:31,
            6:30,
            7:31,
            8:31,
            9:30,
            10:31,
            11:30,
            12:31}

mensal_aberto["gastos_dia"] = mensal_aberto["gasto"] / mensal_aberto["mes"].map(dias_mes)

# %%
mensal_aberto.head()
# Out:
#   dia_mes_ano            uf  gasto  mes   ano  gastos_dia
# 0  2008-02-01  35 São Paulo 172.96    2  2008        6.18
# 1  2008-03-01  35 São Paulo 170.56    3  2008        5.50
# 2  2008-04-01  35 São Paulo 170.34    4  2008        5.68
# 3  2008-05-01  35 São Paulo 172.46    5  2008        5.56
# 4  2008-06-01  35 São Paulo 175.49    6  2008        5.85

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf=='35 São Paulo'"), x="mes", y="gastos_dia", hue="ano", palette="inferno")
plt.xticks(rotation=30)
plt.grid(True, linestyle='--')
plt.ylim(0,12)
plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf=='33 Rio de Janeiro'"), x="mes", y="gastos_dia", hue="ano", palette="inferno")
plt.xticks(rotation=30)
plt.grid(True, linestyle='--')
plt.ylim(0,12)
plt.show()
